# %%
import time
import google.generativeai as genai
import pandas as pd

# Configurer l'API Gemini
api_key = "*******************"  # Remplace par ta clé
genai.configure(api_key=api_key)

# Charger les données d'origine
file_path = r"C:\Users\train_choice.csv"  # Modifie le chemin vers ton dataset initial
dataset = pd.read_csv(file_path)

# Fonction pour interroger l'API Gemini
def get_ai_decision(row):
    prompt = f"""
    Tu es un passager de train et tu dois choisir entre deux options pour ton voyage. Voici les critères importants :
    1. Prix : Le coût du billet en euros. Un prix plus bas est préféré.
    2. Temps : La durée totale du trajet en heures. Un trajet plus court est préféré.
    3. Changements : Le nombre de correspondances pendant le trajet. Moins de changements sont préférés.
    4. Confort : Une mesure inversée du confort (plus bas = plus confortable).

    Voici les deux options disponibles :
    - **Option A : Prix = {row['price_A']} €, Temps = {row['time_A']} heures, Changements = {row['change_A']}, Confort = {row['comfort_A']}
    - **Option B : Prix = {row['price_B']} €, Temps = {row['time_B']} heures, Changements = {row['change_B']}, Confort = {row['comfort_B']}

    En tant que passager, quelle option choisirais-tu ? Réponds par 'A' ou 'B' seulement.
    """
    try:
        # Utiliser le modèle Gemini pour générer une réponse
        model = genai.GenerativeModel(
            model_name="gemini-1.5-flash",
            generation_config={
                "temperature": 0.7,
                "max_output_tokens": 100,
            },
        )
        chat_session = model.start_chat(history=[])
        response = chat_session.send_message(prompt)
        return response.text.strip()
    except Exception as e:
        print(f"Erreur avec l'API pour la ligne {row.name} : {e}")
        return "Erreur"

# Sauvegarde ligne par ligne dans le fichier train_gemini.csv
output_path = r"C:\Users\train_gemini.csv"
with open(output_path, "w") as f:
    # Écrire les en-têtes
    f.write(",".join(dataset.columns) + ",ai_choice\n")

# Traiter ligne par ligne avec respect des limites
for index, row in dataset.iterrows():
    ai_choice = get_ai_decision(row)
    dataset.loc[index, 'ai_choice'] = ai_choice
    # Sauvegarder la ligne dans le fichier
    with open(output_path, "a") as f:
        f.write(",".join(map(str, row.tolist())) + f",{ai_choice}\n")
    print(f"Ligne {index + 1}/{len(dataset)} traitée : {ai_choice}")
    
    # Pause pour respecter les limites de 15 requêtes par minute
    time.sleep(4)  # Pause de 4 secondes

print(f"Traitement terminé. Fichier final sauvegardé dans : {output_path}")
# Out:
# Ligne 1/2929 traitée : A
# Ligne 2/2929 traitée : A
# Ligne 3/2929 traitée : A
# Ligne 4/2929 traitée : B
# Ligne 5/2929 traitée : A
# Ligne 6/2929 traitée : B
# Ligne 7/2929 traitée : A
# Ligne 8/2929 traitée : A
# Ligne 9/2929 traitée : B
# Ligne 10/2929 traitée : B
# Ligne 11/2929 traitée : A
# Ligne 12/2929 traitée : B
# Ligne 13/2929 traitée : B
# Ligne 14/2929 traitée : B
# Ligne 15/2929 traitée : B
# Ligne 16/2929 traitée : B
# Ligne 17/2929 traitée : B
# Ligne 18/2929 traitée : B
# Ligne 19/2929 traitée : B
# Ligne 20/2929 traitée : B
# Ligne 21/2929 traitée : B
# Ligne 22/2929 traitée : A
# Ligne 23/2929 traitée : B
# Ligne 24/2929 traitée : A
# Ligne 25/2929 traitée : A
# Ligne 26/2929 traitée : A
# Ligne 27/2929 traitée : B
# Ligne 28/2929 traitée : B
# Ligne 29/2929 traitée : B
# Ligne 30/2929 traitée : B
# Ligne 31/2929 traitée : B
# Ligne 32/2929 traitée : B
# Ligne 33/2929 traitée : B
# Ligne 34/2929 traitée : B
# Ligne 35/2929 traitée : B
# Ligne 36/2929 traitée : B
# Ligne 37/2929 traitée : B
# Ligne 38/2929 traitée : B
# Ligne 39/2929 traitée : B
# Ligne 40/2929 traitée : A
# Ligne 41/2929 traitée : B
# Ligne 42/2929 traitée : B
# Ligne 43/2929 traitée : B
# Ligne 44/2929 traitée : B
# Ligne 45/2929 traitée : A
# Ligne 46/2929 traitée : B
# Ligne 47/2929 traitée : B
# Ligne 48/2929 traitée : B
# Ligne 49/2929 traitée : A
# Ligne 50/2929 traitée : B
# Ligne 51/2929 traitée : A
# Ligne 52/2929 traitée : B
# Ligne 53/2929 traitée : B
# Ligne 54/2929 traitée : B
# Ligne 55/2929 traitée : B
# Ligne 56/2929 traitée : A
# Ligne 57/2929 traitée : B
# Ligne 58/2929 traitée : A
# Ligne 59/2929 traitée : B
# Ligne 60/2929 traitée : A
# Ligne 61/2929 traitée : B
# Ligne 62/2929 traitée : B
# Ligne 63/2929 traitée : B
# Ligne 64/2929 traitée : A
# Ligne 65/2929 traitée : A
# Ligne 66/2929 traitée : A
# Ligne 67/2929 traitée : B
# Ligne 68/2929 traitée : A
# Ligne 69/2929 traitée : B
# Ligne 70/2929 traitée : B
# Ligne 71/2929 traitée : B
# Ligne 72/2929 traitée : A
# Ligne 73/2929 traitée : A
# Ligne 74/2929 traitée : B
# Ligne 75/2929 traitée : A
# Ligne 76/2929 traitée : B
# Ligne 77/2929 traitée : B
# Ligne 78/2929 traitée : B
# Ligne 79/2929 traitée : B
# Ligne 80/2929 traitée : A
# Ligne 81/2929 traitée : B
# Ligne 82/2929 traitée : A
# Ligne 83/2929 traitée : B
# Ligne 84/2929 traitée : B
# Ligne 85/2929 traitée : A
# Ligne 86/2929 traitée : A
# Ligne 87/2929 traitée : A
# Ligne 88/2929 traitée : B
# Ligne 89/2929 traitée : A
# Ligne 90/2929 traitée : B
# Ligne 91/2929 traitée : B
# Ligne 92/2929 traitée : A
# Ligne 93/2929 traitée : B
# Ligne 94/2929 traitée : B
# Ligne 95/2929 traitée : A
# Ligne 96/2929 traitée : B
# Ligne 97/2929 traitée : B
# Ligne 98/2929 traitée : B
# Ligne 99/2929 traitée : B
# Ligne 100/2929 traitée : B
# Ligne 101/2929 traitée : A
# Ligne 102/2929 traitée : A
# Ligne 103/2929 traitée : A
# Ligne 104/2929 traitée : A
# Ligne 105/2929 traitée : B
# Ligne 106/2929 traitée : B
# Ligne 107/2929 traitée : A
# Ligne 108/2929 traitée : B
# Ligne 109/2929 traitée : B
# Ligne 110/2929 traitée : A
# Ligne 111/2929 traitée : B
# Ligne 112/2929 traitée : B
# Ligne 113/2929 traitée : B
# Ligne 114/2929 traitée : B
# Ligne 115/2929 traitée : B
# Ligne 116/2929 traitée : A
# Ligne 117/2929 traitée : A
# Ligne 118/2929 traitée : B
# Ligne 119/2929 traitée : A
# Ligne 120/2929 traitée : B
# Ligne 121/2929 traitée : B
# Ligne 122/2929 traitée : A
# Ligne 123/2929 traitée : A
# Ligne 124/2929 traitée : B
# Ligne 125/2929 traitée : A
# Ligne 126/2929 traitée : B
# Ligne 127/2929 traitée : B
# Ligne 128/2929 traitée : A
# Ligne 129/2929 traitée : A
# Ligne 130/2929 traitée : A
# Ligne 131/2929 traitée : A
# Ligne 132/2929 traitée : A
# Ligne 133/2929 traitée : B
# Ligne 134/2929 traitée : B
# Ligne 135/2929 traitée : A
# Ligne 136/2929 traitée : A
# Ligne 137/2929 traitée : A
# Ligne 138/2929 traitée : B
# Ligne 139/2929 traitée : B
# Ligne 140/2929 traitée : B
# Ligne 141/2929 traitée : A
# Ligne 142/2929 traitée : A
# Ligne 143/2929 traitée : A
# Ligne 144/2929 traitée : B
# Ligne 145/2929 traitée : B
# Ligne 146/2929 traitée : B
# Ligne 147/2929 traitée : B
# Ligne 148/2929 traitée : B
# Ligne 149/2929 traitée : B
# Ligne 150/2929 traitée : B
# Ligne 151/2929 traitée : A
# Ligne 152/2929 traitée : B
# Ligne 153/2929 traitée : B
# Ligne 154/2929 traitée : A
# Ligne 155/2929 traitée : B
# Ligne 156/2929 traitée : B
# Ligne 157/2929 traitée : B
# Ligne 158/2929 traitée : A
# Ligne 159/2929 traitée : B
# Ligne 160/2929 traitée : B
# Ligne 161/2929 traitée : B
# Ligne 162/2929 traitée : B
# Ligne 163/2929 traitée : A
# Ligne 164/2929 traitée : A
# Ligne 165/2929 traitée : B
# Ligne 166/2929 traitée : B
# Ligne 167/2929 traitée : A
# Ligne 168/2929 traitée : B
# Ligne 169/2929 traitée : A
# Ligne 170/2929 traitée : B
# Ligne 171/2929 traitée : B
# Ligne 172/2929 traitée : B
# Ligne 173/2929 traitée : B
# Ligne 174/2929 traitée : A
# Ligne 175/2929 traitée : B
# Ligne 176/2929 traitée : A
# Ligne 177/2929 traitée : B
# Ligne 178/2929 traitée : B
# Ligne 179/2929 traitée : B
# Ligne 180/2929 traitée : A
# Ligne 181/2929 traitée : B
# Ligne 182/2929 traitée : B
# Ligne 183/2929 traitée : B
# Ligne 184/2929 traitée : B
# Ligne 185/2929 traitée : B
# Ligne 186/2929 traitée : A
# Ligne 187/2929 traitée : B
# Ligne 188/2929 traitée : B
# Ligne 189/2929 traitée : B
# Ligne 190/2929 traitée : A
# Ligne 191/2929 traitée : B
# Ligne 192/2929 traitée : A
# Ligne 193/2929 traitée : A
# Ligne 194/2929 traitée : B
# Ligne 195/2929 traitée : B
# Ligne 196/2929 traitée : A
# Ligne 197/2929 traitée : A
# Ligne 198/2929 traitée : B
# Ligne 199/2929 traitée : A
# Ligne 200/2929 traitée : A
# Ligne 201/2929 traitée : A
# Ligne 202/2929 traitée : A
# Ligne 203/2929 traitée : A
# Ligne 204/2929 traitée : B
# Ligne 205/2929 traitée : B
# Ligne 206/2929 traitée : B
# Ligne 207/2929 traitée : B
# Ligne 208/2929 traitée : A
# Ligne 209/2929 traitée : A
# Ligne 210/2929 traitée : B
# Ligne 211/2929 traitée : B
# Ligne 212/2929 traitée : B
# Ligne 213/2929 traitée : B
# Ligne 214/2929 traitée : B
# Ligne 215/2929 traitée : B
# Ligne 216/2929 traitée : B
# Ligne 217/2929 traitée : A
# Ligne 218/2929 traitée : A
# Ligne 219/2929 traitée : A
# Ligne 220/2929 traitée : B
# Ligne 221/2929 traitée : B
# Ligne 222/2929 traitée : B
# Ligne 223/2929 traitée : A
# Ligne 224/2929 traitée : B
# Ligne 225/2929 traitée : B
# Ligne 226/2929 traitée : A
# Ligne 227/2929 traitée : A
# Ligne 228/2929 traitée : B
# Ligne 229/2929 traitée : B
# Ligne 230/2929 traitée : A
# Ligne 231/2929 traitée : B
# Ligne 232/2929 traitée : B
# Ligne 233/2929 traitée : B
# Ligne 234/2929 traitée : B
# Ligne 235/2929 traitée : A
# Ligne 236/2929 traitée : A
# Ligne 237/2929 traitée : B
# Ligne 238/2929 traitée : B
# Ligne 239/2929 traitée : A
# Ligne 240/2929 traitée : B
# Ligne 241/2929 traitée : B
# Ligne 242/2929 traitée : B
# Erreur avec l'API pour la ligne 242 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 243/2929 traitée : Erreur
# Ligne 244/2929 traitée : A
# Ligne 245/2929 traitée : B
# Ligne 246/2929 traitée : B
# Ligne 247/2929 traitée : A
# Ligne 248/2929 traitée : B
# Ligne 249/2929 traitée : B
# Ligne 250/2929 traitée : A
# Ligne 251/2929 traitée : B
# Ligne 252/2929 traitée : A
# Ligne 253/2929 traitée : B
# Ligne 254/2929 traitée : A
# Ligne 255/2929 traitée : B
# Ligne 256/2929 traitée : B
# Ligne 257/2929 traitée : B
# Ligne 258/2929 traitée : A
# Ligne 259/2929 traitée : B
# Ligne 260/2929 traitée : B
# Ligne 261/2929 traitée : B
# Ligne 262/2929 traitée : B
# Ligne 263/2929 traitée : B
# Ligne 264/2929 traitée : B
# Ligne 265/2929 traitée : B
# Ligne 266/2929 traitée : A
# Ligne 267/2929 traitée : A
# Ligne 268/2929 traitée : B
# Ligne 269/2929 traitée : B
# Ligne 270/2929 traitée : A
# Ligne 271/2929 traitée : A
# Ligne 272/2929 traitée : A
# Ligne 273/2929 traitée : B
# Ligne 274/2929 traitée : B
# Ligne 275/2929 traitée : A
# Ligne 276/2929 traitée : A
# Ligne 277/2929 traitée : B
# Ligne 278/2929 traitée : B
# Ligne 279/2929 traitée : A
# Ligne 280/2929 traitée : B
# Ligne 281/2929 traitée : B
# Ligne 282/2929 traitée : A
# Ligne 283/2929 traitée : B
# Ligne 284/2929 traitée : B
# Ligne 285/2929 traitée : A
# Ligne 286/2929 traitée : B
# Ligne 287/2929 traitée : A
# Ligne 288/2929 traitée : A
# Ligne 289/2929 traitée : B
# Ligne 290/2929 traitée : B
# Ligne 291/2929 traitée : A
# Ligne 292/2929 traitée : A
# Ligne 293/2929 traitée : B
# Ligne 294/2929 traitée : A
# Ligne 295/2929 traitée : B
# Ligne 296/2929 traitée : B
# Ligne 297/2929 traitée : B
# Ligne 298/2929 traitée : B
# Ligne 299/2929 traitée : B
# Ligne 300/2929 traitée : B
# Ligne 301/2929 traitée : A
# Ligne 302/2929 traitée : B
# Ligne 303/2929 traitée : B
# Ligne 304/2929 traitée : A
# Ligne 305/2929 traitée : B
# Ligne 306/2929 traitée : B
# Ligne 307/2929 traitée : B
# Ligne 308/2929 traitée : A
# Ligne 309/2929 traitée : B
# Ligne 310/2929 traitée : B
# Ligne 311/2929 traitée : B
# Ligne 312/2929 traitée : B
# Ligne 313/2929 traitée : B
# Ligne 314/2929 traitée : B
# Ligne 315/2929 traitée : B
# Ligne 316/2929 traitée : B
# Ligne 317/2929 traitée : A
# Ligne 318/2929 traitée : A
# Ligne 319/2929 traitée : B
# Ligne 320/2929 traitée : A
# Ligne 321/2929 traitée : B
# Ligne 322/2929 traitée : B
# Ligne 323/2929 traitée : A
# Ligne 324/2929 traitée : A
# Ligne 325/2929 traitée : B
# Ligne 326/2929 traitée : B
# Ligne 327/2929 traitée : B
# Ligne 328/2929 traitée : B
# Ligne 329/2929 traitée : A
# Ligne 330/2929 traitée : B
# Ligne 331/2929 traitée : A
# Ligne 332/2929 traitée : B
# Ligne 333/2929 traitée : A
# Ligne 334/2929 traitée : B
# Ligne 335/2929 traitée : A
# Ligne 336/2929 traitée : B
# Ligne 337/2929 traitée : B
# Ligne 338/2929 traitée : A
# Erreur avec l'API pour la ligne 338 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 339/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 339 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 340/2929 traitée : Erreur
# Ligne 341/2929 traitée : A
# Ligne 342/2929 traitée : A
# Ligne 343/2929 traitée : B
# Ligne 344/2929 traitée : B
# Ligne 345/2929 traitée : A
# Ligne 346/2929 traitée : B
# Ligne 347/2929 traitée : A
# Ligne 348/2929 traitée : A
# Ligne 349/2929 traitée : A
# Ligne 350/2929 traitée : B
# Ligne 351/2929 traitée : B
# Ligne 352/2929 traitée : B
# Ligne 353/2929 traitée : B
# Ligne 354/2929 traitée : B
# Ligne 355/2929 traitée : B
# Ligne 356/2929 traitée : A
# Ligne 357/2929 traitée : B
# Ligne 358/2929 traitée : B
# Ligne 359/2929 traitée : B
# Ligne 360/2929 traitée : B
# Ligne 361/2929 traitée : A
# Ligne 362/2929 traitée : B
# Ligne 363/2929 traitée : A
# Ligne 364/2929 traitée : B
# Ligne 365/2929 traitée : B
# Ligne 366/2929 traitée : B
# Ligne 367/2929 traitée : B
# Ligne 368/2929 traitée : B
# Ligne 369/2929 traitée : A
# Ligne 370/2929 traitée : B
# Ligne 371/2929 traitée : A
# Ligne 372/2929 traitée : A
# Ligne 373/2929 traitée : B
# Ligne 374/2929 traitée : B
# Ligne 375/2929 traitée : B
# Ligne 376/2929 traitée : B
# Ligne 377/2929 traitée : B
# Ligne 378/2929 traitée : A
# Ligne 379/2929 traitée : B
# Ligne 380/2929 traitée : B
# Ligne 381/2929 traitée : B
# Ligne 382/2929 traitée : A
# Ligne 383/2929 traitée : B
# Ligne 384/2929 traitée : B
# Ligne 385/2929 traitée : B
# Ligne 386/2929 traitée : B
# Ligne 387/2929 traitée : B
# Ligne 388/2929 traitée : A
# Ligne 389/2929 traitée : A
# Ligne 390/2929 traitée : B
# Ligne 391/2929 traitée : A
# Ligne 392/2929 traitée : B
# Ligne 393/2929 traitée : A
# Ligne 394/2929 traitée : B
# Ligne 395/2929 traitée : A
# Ligne 396/2929 traitée : B
# Ligne 397/2929 traitée : B
# Ligne 398/2929 traitée : B
# Ligne 399/2929 traitée : A
# Ligne 400/2929 traitée : A
# Ligne 401/2929 traitée : B
# Ligne 402/2929 traitée : B
# Ligne 403/2929 traitée : A
# Ligne 404/2929 traitée : B
# Ligne 405/2929 traitée : A
# Ligne 406/2929 traitée : B
# Ligne 407/2929 traitée : B
# Ligne 408/2929 traitée : B
# Ligne 409/2929 traitée : B
# Ligne 410/2929 traitée : B
# Ligne 411/2929 traitée : B
# Ligne 412/2929 traitée : B
# Ligne 413/2929 traitée : B
# Ligne 414/2929 traitée : B
# Ligne 415/2929 traitée : A
# Ligne 416/2929 traitée : B
# Ligne 417/2929 traitée : B
# Ligne 418/2929 traitée : B
# Ligne 419/2929 traitée : A
# Ligne 420/2929 traitée : B
# Ligne 421/2929 traitée : A
# Ligne 422/2929 traitée : A
# Ligne 423/2929 traitée : B
# Ligne 424/2929 traitée : B
# Ligne 425/2929 traitée : A
# Ligne 426/2929 traitée : B
# Ligne 427/2929 traitée : B
# Ligne 428/2929 traitée : A
# Ligne 429/2929 traitée : B
# Ligne 430/2929 traitée : B
# Ligne 431/2929 traitée : A
# Ligne 432/2929 traitée : A
# Ligne 433/2929 traitée : B
# Ligne 434/2929 traitée : B
# Ligne 435/2929 traitée : B
# Ligne 436/2929 traitée : B
# Ligne 437/2929 traitée : A
# Ligne 438/2929 traitée : B
# Ligne 439/2929 traitée : B
# Ligne 440/2929 traitée : B
# Ligne 441/2929 traitée : B
# Ligne 442/2929 traitée : B
# Ligne 443/2929 traitée : B
# Ligne 444/2929 traitée : B
# Ligne 445/2929 traitée : B
# Ligne 446/2929 traitée : A
# Ligne 447/2929 traitée : B
# Ligne 448/2929 traitée : B
# Ligne 449/2929 traitée : B
# Ligne 450/2929 traitée : B
# Ligne 451/2929 traitée : B
# Ligne 452/2929 traitée : B
# Ligne 453/2929 traitée : B
# Ligne 454/2929 traitée : B
# Ligne 455/2929 traitée : A
# Ligne 456/2929 traitée : B
# Ligne 457/2929 traitée : A
# Ligne 458/2929 traitée : B
# Ligne 459/2929 traitée : B
# Ligne 460/2929 traitée : B
# Ligne 461/2929 traitée : B
# Ligne 462/2929 traitée : B
# Ligne 463/2929 traitée : A
# Ligne 464/2929 traitée : B
# Ligne 465/2929 traitée : A
# Ligne 466/2929 traitée : B
# Ligne 467/2929 traitée : B
# Ligne 468/2929 traitée : B
# Ligne 469/2929 traitée : B
# Ligne 470/2929 traitée : A
# Ligne 471/2929 traitée : A
# Ligne 472/2929 traitée : A
# Ligne 473/2929 traitée : A
# Ligne 474/2929 traitée : A
# Ligne 475/2929 traitée : A
# Ligne 476/2929 traitée : A
# Ligne 477/2929 traitée : B
# Ligne 478/2929 traitée : B
# Ligne 479/2929 traitée : A
# Ligne 480/2929 traitée : B
# Ligne 481/2929 traitée : B
# Ligne 482/2929 traitée : B
# Ligne 483/2929 traitée : B
# Ligne 484/2929 traitée : A
# Ligne 485/2929 traitée : A
# Ligne 486/2929 traitée : B
# Ligne 487/2929 traitée : B
# Ligne 488/2929 traitée : B
# Ligne 489/2929 traitée : B
# Ligne 490/2929 traitée : A
# Ligne 491/2929 traitée : B
# Ligne 492/2929 traitée : B
# Ligne 493/2929 traitée : A
# Ligne 494/2929 traitée : B
# Ligne 495/2929 traitée : A
# Ligne 496/2929 traitée : A
# Ligne 497/2929 traitée : B
# Ligne 498/2929 traitée : B
# Ligne 499/2929 traitée : A
# Ligne 500/2929 traitée : B
# Ligne 501/2929 traitée : B
# Ligne 502/2929 traitée : B
# Ligne 503/2929 traitée : B
# Ligne 504/2929 traitée : B
# Ligne 505/2929 traitée : A
# Ligne 506/2929 traitée : B
# Ligne 507/2929 traitée : B
# Ligne 508/2929 traitée : A
# Ligne 509/2929 traitée : A
# Ligne 510/2929 traitée : A
# Ligne 511/2929 traitée : A
# Ligne 512/2929 traitée : A
# Ligne 513/2929 traitée : B
# Ligne 514/2929 traitée : A
# Ligne 515/2929 traitée : A
# Ligne 516/2929 traitée : B
# Ligne 517/2929 traitée : B
# Ligne 518/2929 traitée : B
# Ligne 519/2929 traitée : B
# Ligne 520/2929 traitée : B
# Ligne 521/2929 traitée : B
# Ligne 522/2929 traitée : A
# Ligne 523/2929 traitée : B
# Ligne 524/2929 traitée : A
# Ligne 525/2929 traitée : A
# Ligne 526/2929 traitée : B
# Ligne 527/2929 traitée : B
# Ligne 528/2929 traitée : A
# Ligne 529/2929 traitée : A
# Ligne 530/2929 traitée : A
# Ligne 531/2929 traitée : B
# Ligne 532/2929 traitée : B
# Ligne 533/2929 traitée : B
# Ligne 534/2929 traitée : A
# Ligne 535/2929 traitée : B
# Ligne 536/2929 traitée : B
# Ligne 537/2929 traitée : B
# Ligne 538/2929 traitée : B
# Ligne 539/2929 traitée : B
# Ligne 540/2929 traitée : B
# Ligne 541/2929 traitée : B
# Ligne 542/2929 traitée : B
# Ligne 543/2929 traitée : B
# Ligne 544/2929 traitée : B
# Ligne 545/2929 traitée : B
# Ligne 546/2929 traitée : A
# Ligne 547/2929 traitée : B
# Ligne 548/2929 traitée : A
# Ligne 549/2929 traitée : B
# Ligne 550/2929 traitée : B
# Ligne 551/2929 traitée : A
# Ligne 552/2929 traitée : B
# Ligne 553/2929 traitée : B
# Ligne 554/2929 traitée : B
# Ligne 555/2929 traitée : B
# Ligne 556/2929 traitée : B
# Ligne 557/2929 traitée : B
# Ligne 558/2929 traitée : B
# Ligne 559/2929 traitée : B
# Ligne 560/2929 traitée : B
# Ligne 561/2929 traitée : A
# Ligne 562/2929 traitée : A
# Ligne 563/2929 traitée : B
# Ligne 564/2929 traitée : A
# Ligne 565/2929 traitée : B
# Ligne 566/2929 traitée : B
# Ligne 567/2929 traitée : B
# Ligne 568/2929 traitée : B
# Ligne 569/2929 traitée : B
# Ligne 570/2929 traitée : A
# Ligne 571/2929 traitée : A
# Ligne 572/2929 traitée : A
# Ligne 573/2929 traitée : B
# Ligne 574/2929 traitée : B
# Ligne 575/2929 traitée : B
# Ligne 576/2929 traitée : B
# Ligne 577/2929 traitée : B
# Ligne 578/2929 traitée : B
# Ligne 579/2929 traitée : A
# Ligne 580/2929 traitée : A
# Ligne 581/2929 traitée : A
# Ligne 582/2929 traitée : B
# Ligne 583/2929 traitée : A
# Ligne 584/2929 traitée : B
# Ligne 585/2929 traitée : A
# Ligne 586/2929 traitée : B
# Ligne 587/2929 traitée : A
# Ligne 588/2929 traitée : A
# Ligne 589/2929 traitée : B
# Ligne 590/2929 traitée : B
# Ligne 591/2929 traitée : B
# Ligne 592/2929 traitée : B
# Ligne 593/2929 traitée : B
# Ligne 594/2929 traitée : A
# Ligne 595/2929 traitée : B
# Ligne 596/2929 traitée : B
# Ligne 597/2929 traitée : B
# Ligne 598/2929 traitée : A
# Ligne 599/2929 traitée : B
# Ligne 600/2929 traitée : A
# Ligne 601/2929 traitée : B
# Ligne 602/2929 traitée : B
# Ligne 603/2929 traitée : B
# Ligne 604/2929 traitée : A
# Ligne 605/2929 traitée : B
# Ligne 606/2929 traitée : B
# Ligne 607/2929 traitée : A
# Ligne 608/2929 traitée : B
# Ligne 609/2929 traitée : B
# Ligne 610/2929 traitée : A
# Ligne 611/2929 traitée : B
# Ligne 612/2929 traitée : A
# Ligne 613/2929 traitée : B
# Ligne 614/2929 traitée : B
# Ligne 615/2929 traitée : A
# Ligne 616/2929 traitée : B
# Ligne 617/2929 traitée : A
# Ligne 618/2929 traitée : B
# Ligne 619/2929 traitée : B
# Ligne 620/2929 traitée : B
# Ligne 621/2929 traitée : B
# Ligne 622/2929 traitée : B
# Ligne 623/2929 traitée : B
# Ligne 624/2929 traitée : B
# Ligne 625/2929 traitée : A
# Ligne 626/2929 traitée : B
# Ligne 627/2929 traitée : B
# Ligne 628/2929 traitée : A
# Ligne 629/2929 traitée : B
# Ligne 630/2929 traitée : B
# Ligne 631/2929 traitée : A
# Ligne 632/2929 traitée : B
# Ligne 633/2929 traitée : A
# Ligne 634/2929 traitée : B
# Ligne 635/2929 traitée : B
# Ligne 636/2929 traitée : B
# Ligne 637/2929 traitée : B
# Ligne 638/2929 traitée : B
# Ligne 639/2929 traitée : B
# Ligne 640/2929 traitée : B
# Ligne 641/2929 traitée : B
# Ligne 642/2929 traitée : B
# Ligne 643/2929 traitée : B
# Ligne 644/2929 traitée : B
# Ligne 645/2929 traitée : A
# Ligne 646/2929 traitée : B
# Ligne 647/2929 traitée : B
# Ligne 648/2929 traitée : B
# Ligne 649/2929 traitée : B
# Ligne 650/2929 traitée : A
# Ligne 651/2929 traitée : A
# Ligne 652/2929 traitée : A
# Ligne 653/2929 traitée : A
# Ligne 654/2929 traitée : A
# Ligne 655/2929 traitée : B
# Ligne 656/2929 traitée : B
# Ligne 657/2929 traitée : B
# Ligne 658/2929 traitée : A
# Ligne 659/2929 traitée : A
# Ligne 660/2929 traitée : A
# Ligne 661/2929 traitée : B
# Ligne 662/2929 traitée : B
# Ligne 663/2929 traitée : A
# Ligne 664/2929 traitée : B
# Ligne 665/2929 traitée : B
# Ligne 666/2929 traitée : B
# Ligne 667/2929 traitée : B
# Ligne 668/2929 traitée : A
# Ligne 669/2929 traitée : B
# Ligne 670/2929 traitée : A
# Ligne 671/2929 traitée : B
# Ligne 672/2929 traitée : B
# Ligne 673/2929 traitée : B
# Ligne 674/2929 traitée : B
# Ligne 675/2929 traitée : B
# Ligne 676/2929 traitée : B
# Ligne 677/2929 traitée : A
# Ligne 678/2929 traitée : B
# Ligne 679/2929 traitée : A
# Ligne 680/2929 traitée : A
# Ligne 681/2929 traitée : B
# Ligne 682/2929 traitée : B
# Ligne 683/2929 traitée : B
# Ligne 684/2929 traitée : A
# Ligne 685/2929 traitée : A
# Ligne 686/2929 traitée : B
# Ligne 687/2929 traitée : B
# Ligne 688/2929 traitée : A
# Ligne 689/2929 traitée : B
# Ligne 690/2929 traitée : B
# Ligne 691/2929 traitée : A
# Ligne 692/2929 traitée : B
# Ligne 693/2929 traitée : A
# Ligne 694/2929 traitée : B
# Ligne 695/2929 traitée : B
# Ligne 696/2929 traitée : A
# Ligne 697/2929 traitée : B
# Ligne 698/2929 traitée : A
# Ligne 699/2929 traitée : A
# Ligne 700/2929 traitée : B
# Ligne 701/2929 traitée : B
# Ligne 702/2929 traitée : B
# Ligne 703/2929 traitée : A
# Ligne 704/2929 traitée : A
# Ligne 705/2929 traitée : B
# Ligne 706/2929 traitée : B
# Ligne 707/2929 traitée : B
# Ligne 708/2929 traitée : A
# Ligne 709/2929 traitée : B
# Ligne 710/2929 traitée : A
# Ligne 711/2929 traitée : B
# Ligne 712/2929 traitée : A
# Ligne 713/2929 traitée : B
# Ligne 714/2929 traitée : A
# Ligne 715/2929 traitée : A
# Ligne 716/2929 traitée : B
# Ligne 717/2929 traitée : B
# Ligne 718/2929 traitée : B
# Ligne 719/2929 traitée : B
# Ligne 720/2929 traitée : A
# Ligne 721/2929 traitée : B
# Ligne 722/2929 traitée : B
# Ligne 723/2929 traitée : A
# Ligne 724/2929 traitée : B
# Ligne 725/2929 traitée : B
# Ligne 726/2929 traitée : A
# Ligne 727/2929 traitée : B
# Ligne 728/2929 traitée : B
# Ligne 729/2929 traitée : B
# Ligne 730/2929 traitée : B
# Ligne 731/2929 traitée : A
# Ligne 732/2929 traitée : B
# Ligne 733/2929 traitée : B
# Ligne 734/2929 traitée : A
# Ligne 735/2929 traitée : A
# Ligne 736/2929 traitée : B
# Ligne 737/2929 traitée : B
# Ligne 738/2929 traitée : B
# Ligne 739/2929 traitée : B
# Ligne 740/2929 traitée : B
# Ligne 741/2929 traitée : B
# Ligne 742/2929 traitée : A
# Ligne 743/2929 traitée : B
# Ligne 744/2929 traitée : A
# Ligne 745/2929 traitée : A
# Ligne 746/2929 traitée : B
# Ligne 747/2929 traitée : B
# Ligne 748/2929 traitée : A
# Ligne 749/2929 traitée : B
# Ligne 750/2929 traitée : B
# Ligne 751/2929 traitée : B
# Ligne 752/2929 traitée : B
# Ligne 753/2929 traitée : B
# Ligne 754/2929 traitée : B
# Ligne 755/2929 traitée : B
# Ligne 756/2929 traitée : B
# Ligne 757/2929 traitée : B
# Ligne 758/2929 traitée : B
# Ligne 759/2929 traitée : A
# Ligne 760/2929 traitée : B
# Ligne 761/2929 traitée : A
# Ligne 762/2929 traitée : B
# Ligne 763/2929 traitée : B
# Ligne 764/2929 traitée : A
# Ligne 765/2929 traitée : A
# Ligne 766/2929 traitée : A
# Ligne 767/2929 traitée : A
# Ligne 768/2929 traitée : B
# Ligne 769/2929 traitée : A
# Ligne 770/2929 traitée : B
# Ligne 771/2929 traitée : B
# Ligne 772/2929 traitée : B
# Ligne 773/2929 traitée : A
# Ligne 774/2929 traitée : A
# Ligne 775/2929 traitée : B
# Ligne 776/2929 traitée : B
# Ligne 777/2929 traitée : B
# Ligne 778/2929 traitée : B
# Ligne 779/2929 traitée : B
# Ligne 780/2929 traitée : A
# Ligne 781/2929 traitée : A
# Ligne 782/2929 traitée : B
# Ligne 783/2929 traitée : A
# Ligne 784/2929 traitée : B
# Ligne 785/2929 traitée : A
# Ligne 786/2929 traitée : B
# Ligne 787/2929 traitée : A
# Ligne 788/2929 traitée : A
# Ligne 789/2929 traitée : A
# Ligne 790/2929 traitée : B
# Ligne 791/2929 traitée : B
# Ligne 792/2929 traitée : B
# Ligne 793/2929 traitée : A
# Ligne 794/2929 traitée : B
# Ligne 795/2929 traitée : B
# Ligne 796/2929 traitée : B
# Ligne 797/2929 traitée : A
# Ligne 798/2929 traitée : A
# Ligne 799/2929 traitée : B
# Ligne 800/2929 traitée : B
# Ligne 801/2929 traitée : B
# Ligne 802/2929 traitée : B
# Ligne 803/2929 traitée : B
# Ligne 804/2929 traitée : B
# Ligne 805/2929 traitée : B
# Ligne 806/2929 traitée : A
# Ligne 807/2929 traitée : B
# Ligne 808/2929 traitée : B
# Ligne 809/2929 traitée : B
# Ligne 810/2929 traitée : B
# Ligne 811/2929 traitée : B
# Ligne 812/2929 traitée : B
# Ligne 813/2929 traitée : A
# Ligne 814/2929 traitée : A
# Ligne 815/2929 traitée : B
# Ligne 816/2929 traitée : B
# Ligne 817/2929 traitée : A
# Ligne 818/2929 traitée : A
# Ligne 819/2929 traitée : A
# Ligne 820/2929 traitée : B
# Ligne 821/2929 traitée : B
# Ligne 822/2929 traitée : B
# Ligne 823/2929 traitée : B
# Ligne 824/2929 traitée : B
# Ligne 825/2929 traitée : A
# Ligne 826/2929 traitée : A
# Ligne 827/2929 traitée : A
# Ligne 828/2929 traitée : B
# Ligne 829/2929 traitée : B
# Ligne 830/2929 traitée : A
# Ligne 831/2929 traitée : B
# Ligne 832/2929 traitée : B
# Ligne 833/2929 traitée : B
# Ligne 834/2929 traitée : B
# Ligne 835/2929 traitée : B
# Ligne 836/2929 traitée : A
# Ligne 837/2929 traitée : B
# Ligne 838/2929 traitée : B
# Ligne 839/2929 traitée : B
# Ligne 840/2929 traitée : B
# Ligne 841/2929 traitée : B
# Ligne 842/2929 traitée : B
# Ligne 843/2929 traitée : A
# Ligne 844/2929 traitée : B
# Ligne 845/2929 traitée : B
# Ligne 846/2929 traitée : B
# Ligne 847/2929 traitée : A
# Ligne 848/2929 traitée : B
# Ligne 849/2929 traitée : B
# Ligne 850/2929 traitée : B
# Ligne 851/2929 traitée : A
# Ligne 852/2929 traitée : B
# Ligne 853/2929 traitée : B
# Ligne 854/2929 traitée : B
# Ligne 855/2929 traitée : B
# Ligne 856/2929 traitée : B
# Ligne 857/2929 traitée : B
# Ligne 858/2929 traitée : A
# Ligne 859/2929 traitée : A
# Ligne 860/2929 traitée : B
# Ligne 861/2929 traitée : B
# Ligne 862/2929 traitée : B
# Ligne 863/2929 traitée : B
# Ligne 864/2929 traitée : B
# Ligne 865/2929 traitée : B
# Ligne 866/2929 traitée : A
# Ligne 867/2929 traitée : B
# Ligne 868/2929 traitée : B
# Ligne 869/2929 traitée : A
# Ligne 870/2929 traitée : B
# Ligne 871/2929 traitée : B
# Ligne 872/2929 traitée : B
# Ligne 873/2929 traitée : A
# Ligne 874/2929 traitée : B
# Ligne 875/2929 traitée : B
# Ligne 876/2929 traitée : B
# Ligne 877/2929 traitée : A
# Ligne 878/2929 traitée : A
# Ligne 879/2929 traitée : A
# Ligne 880/2929 traitée : B
# Ligne 881/2929 traitée : B
# Ligne 882/2929 traitée : A
# Ligne 883/2929 traitée : B
# Ligne 884/2929 traitée : B
# Ligne 885/2929 traitée : B
# Ligne 886/2929 traitée : B
# Ligne 887/2929 traitée : A
# Ligne 888/2929 traitée : B
# Ligne 889/2929 traitée : A
# Ligne 890/2929 traitée : B
# Ligne 891/2929 traitée : B
# Ligne 892/2929 traitée : B
# Ligne 893/2929 traitée : B
# Ligne 894/2929 traitée : B
# Ligne 895/2929 traitée : A
# Ligne 896/2929 traitée : A
# Ligne 897/2929 traitée : A
# Ligne 898/2929 traitée : B
# Ligne 899/2929 traitée : A
# Ligne 900/2929 traitée : A
# Ligne 901/2929 traitée : B
# Ligne 902/2929 traitée : B
# Ligne 903/2929 traitée : A
# Ligne 904/2929 traitée : A
# Ligne 905/2929 traitée : A
# Ligne 906/2929 traitée : A
# Ligne 907/2929 traitée : B
# Ligne 908/2929 traitée : B
# Ligne 909/2929 traitée : A
# Ligne 910/2929 traitée : B
# Ligne 911/2929 traitée : A
# Ligne 912/2929 traitée : B
# Ligne 913/2929 traitée : A
# Ligne 914/2929 traitée : B
# Ligne 915/2929 traitée : B
# Ligne 916/2929 traitée : B
# Ligne 917/2929 traitée : B
# Ligne 918/2929 traitée : B
# Erreur avec l'API pour la ligne 918 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 919/2929 traitée : Erreur
# Ligne 920/2929 traitée : B
# Ligne 921/2929 traitée : B
# Ligne 922/2929 traitée : A
# Ligne 923/2929 traitée : B
# Ligne 924/2929 traitée : B
# Ligne 925/2929 traitée : A
# Ligne 926/2929 traitée : B
# Ligne 927/2929 traitée : B
# Ligne 928/2929 traitée : A
# Ligne 929/2929 traitée : A
# Ligne 930/2929 traitée : A
# Ligne 931/2929 traitée : B
# Ligne 932/2929 traitée : B
# Erreur avec l'API pour la ligne 932 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 933/2929 traitée : Erreur
# Ligne 934/2929 traitée : B
# Ligne 935/2929 traitée : B
# Ligne 936/2929 traitée : B
# Ligne 937/2929 traitée : B
# Ligne 938/2929 traitée : A
# Ligne 939/2929 traitée : A
# Ligne 940/2929 traitée : A
# Ligne 941/2929 traitée : A
# Ligne 942/2929 traitée : B
# Ligne 943/2929 traitée : B
# Ligne 944/2929 traitée : B
# Ligne 945/2929 traitée : A
# Ligne 946/2929 traitée : B
# Ligne 947/2929 traitée : B
# Ligne 948/2929 traitée : A
# Ligne 949/2929 traitée : B
# Ligne 950/2929 traitée : B
# Ligne 951/2929 traitée : B
# Ligne 952/2929 traitée : B
# Ligne 953/2929 traitée : A
# Ligne 954/2929 traitée : A
# Ligne 955/2929 traitée : A
# Ligne 956/2929 traitée : B
# Ligne 957/2929 traitée : B
# Ligne 958/2929 traitée : A
# Ligne 959/2929 traitée : A
# Ligne 960/2929 traitée : B
# Ligne 961/2929 traitée : B
# Ligne 962/2929 traitée : A
# Ligne 963/2929 traitée : B
# Ligne 964/2929 traitée : A
# Ligne 965/2929 traitée : B
# Ligne 966/2929 traitée : B
# Ligne 967/2929 traitée : B
# Ligne 968/2929 traitée : A
# Ligne 969/2929 traitée : A
# Ligne 970/2929 traitée : B
# Ligne 971/2929 traitée : A
# Ligne 972/2929 traitée : B
# Ligne 973/2929 traitée : B
# Ligne 974/2929 traitée : A
# Ligne 975/2929 traitée : B
# Ligne 976/2929 traitée : A
# Ligne 977/2929 traitée : B
# Ligne 978/2929 traitée : A
# Ligne 979/2929 traitée : B
# Ligne 980/2929 traitée : B
# Ligne 981/2929 traitée : B
# Ligne 982/2929 traitée : B
# Ligne 983/2929 traitée : B
# Ligne 984/2929 traitée : A
# Ligne 985/2929 traitée : A
# Ligne 986/2929 traitée : A
# Ligne 987/2929 traitée : B
# Ligne 988/2929 traitée : B
# Ligne 989/2929 traitée : B
# Ligne 990/2929 traitée : B
# Ligne 991/2929 traitée : A
# Ligne 992/2929 traitée : B
# Ligne 993/2929 traitée : B
# Ligne 994/2929 traitée : B
# Ligne 995/2929 traitée : B
# Ligne 996/2929 traitée : B
# Ligne 997/2929 traitée : B
# Ligne 998/2929 traitée : A
# Ligne 999/2929 traitée : A
# Ligne 1000/2929 traitée : B
# Ligne 1001/2929 traitée : B
# Ligne 1002/2929 traitée : B
# Ligne 1003/2929 traitée : A
# Ligne 1004/2929 traitée : A
# Ligne 1005/2929 traitée : B
# Ligne 1006/2929 traitée : A
# Ligne 1007/2929 traitée : B
# Ligne 1008/2929 traitée : B
# Ligne 1009/2929 traitée : B
# Ligne 1010/2929 traitée : B
# Ligne 1011/2929 traitée : B
# Ligne 1012/2929 traitée : B
# Ligne 1013/2929 traitée : B
# Ligne 1014/2929 traitée : A
# Ligne 1015/2929 traitée : B
# Ligne 1016/2929 traitée : A
# Ligne 1017/2929 traitée : A
# Ligne 1018/2929 traitée : B
# Ligne 1019/2929 traitée : B
# Ligne 1020/2929 traitée : A
# Ligne 1021/2929 traitée : B
# Ligne 1022/2929 traitée : B
# Ligne 1023/2929 traitée : B
# Ligne 1024/2929 traitée : B
# Ligne 1025/2929 traitée : B
# Ligne 1026/2929 traitée : B
# Ligne 1027/2929 traitée : B
# Ligne 1028/2929 traitée : A
# Ligne 1029/2929 traitée : A
# Ligne 1030/2929 traitée : A
# Ligne 1031/2929 traitée : A
# Ligne 1032/2929 traitée : A
# Ligne 1033/2929 traitée : B
# Ligne 1034/2929 traitée : B
# Ligne 1035/2929 traitée : B
# Ligne 1036/2929 traitée : A
# Ligne 1037/2929 traitée : B
# Ligne 1038/2929 traitée : B
# Ligne 1039/2929 traitée : B
# Ligne 1040/2929 traitée : B
# Ligne 1041/2929 traitée : B
# Ligne 1042/2929 traitée : B
# Ligne 1043/2929 traitée : B
# Ligne 1044/2929 traitée : B
# Ligne 1045/2929 traitée : A
# Ligne 1046/2929 traitée : B
# Ligne 1047/2929 traitée : B
# Ligne 1048/2929 traitée : B
# Ligne 1049/2929 traitée : B
# Ligne 1050/2929 traitée : B
# Ligne 1051/2929 traitée : B
# Ligne 1052/2929 traitée : B
# Ligne 1053/2929 traitée : A
# Ligne 1054/2929 traitée : B
# Ligne 1055/2929 traitée : B
# Ligne 1056/2929 traitée : A
# Ligne 1057/2929 traitée : B
# Ligne 1058/2929 traitée : A
# Ligne 1059/2929 traitée : A
# Ligne 1060/2929 traitée : B
# Ligne 1061/2929 traitée : B
# Ligne 1062/2929 traitée : B
# Ligne 1063/2929 traitée : B
# Ligne 1064/2929 traitée : A
# Ligne 1065/2929 traitée : A
# Ligne 1066/2929 traitée : B
# Ligne 1067/2929 traitée : A
# Ligne 1068/2929 traitée : A
# Ligne 1069/2929 traitée : B
# Ligne 1070/2929 traitée : B
# Ligne 1071/2929 traitée : B
# Ligne 1072/2929 traitée : B
# Ligne 1073/2929 traitée : B
# Ligne 1074/2929 traitée : B
# Ligne 1075/2929 traitée : B
# Ligne 1076/2929 traitée : B
# Ligne 1077/2929 traitée : B
# Ligne 1078/2929 traitée : B
# Ligne 1079/2929 traitée : A
# Ligne 1080/2929 traitée : A
# Ligne 1081/2929 traitée : B
# Ligne 1082/2929 traitée : A
# Ligne 1083/2929 traitée : B
# Ligne 1084/2929 traitée : B
# Ligne 1085/2929 traitée : B
# Ligne 1086/2929 traitée : A
# Ligne 1087/2929 traitée : B
# Ligne 1088/2929 traitée : A
# Ligne 1089/2929 traitée : B
# Ligne 1090/2929 traitée : B
# Ligne 1091/2929 traitée : A
# Ligne 1092/2929 traitée : B
# Ligne 1093/2929 traitée : B
# Ligne 1094/2929 traitée : B
# Ligne 1095/2929 traitée : B
# Ligne 1096/2929 traitée : B
# Ligne 1097/2929 traitée : B
# Ligne 1098/2929 traitée : B
# Ligne 1099/2929 traitée : A
# Ligne 1100/2929 traitée : B
# Ligne 1101/2929 traitée : A
# Ligne 1102/2929 traitée : A
# Ligne 1103/2929 traitée : B
# Ligne 1104/2929 traitée : B
# Ligne 1105/2929 traitée : B
# Ligne 1106/2929 traitée : A
# Ligne 1107/2929 traitée : B
# Ligne 1108/2929 traitée : A
# Ligne 1109/2929 traitée : B
# Ligne 1110/2929 traitée : A
# Ligne 1111/2929 traitée : A
# Ligne 1112/2929 traitée : B
# Ligne 1113/2929 traitée : B
# Ligne 1114/2929 traitée : B
# Ligne 1115/2929 traitée : B
# Ligne 1116/2929 traitée : A
# Ligne 1117/2929 traitée : B
# Ligne 1118/2929 traitée : B
# Ligne 1119/2929 traitée : A
# Ligne 1120/2929 traitée : A
# Ligne 1121/2929 traitée : B
# Ligne 1122/2929 traitée : A
# Ligne 1123/2929 traitée : A
# Ligne 1124/2929 traitée : B
# Ligne 1125/2929 traitée : B
# Ligne 1126/2929 traitée : B
# Ligne 1127/2929 traitée : B
# Ligne 1128/2929 traitée : A
# Ligne 1129/2929 traitée : A
# Ligne 1130/2929 traitée : B
# Ligne 1131/2929 traitée : B
# Ligne 1132/2929 traitée : B
# Ligne 1133/2929 traitée : B
# Ligne 1134/2929 traitée : B
# Ligne 1135/2929 traitée : B
# Ligne 1136/2929 traitée : A
# Ligne 1137/2929 traitée : B
# Ligne 1138/2929 traitée : B
# Ligne 1139/2929 traitée : B
# Ligne 1140/2929 traitée : B
# Ligne 1141/2929 traitée : A
# Ligne 1142/2929 traitée : B
# Ligne 1143/2929 traitée : B
# Ligne 1144/2929 traitée : A
# Ligne 1145/2929 traitée : B
# Ligne 1146/2929 traitée : B
# Ligne 1147/2929 traitée : A
# Ligne 1148/2929 traitée : B
# Ligne 1149/2929 traitée : B
# Ligne 1150/2929 traitée : B
# Ligne 1151/2929 traitée : B
# Ligne 1152/2929 traitée : B
# Ligne 1153/2929 traitée : A
# Ligne 1154/2929 traitée : B
# Ligne 1155/2929 traitée : A
# Ligne 1156/2929 traitée : B
# Ligne 1157/2929 traitée : B
# Ligne 1158/2929 traitée : B
# Ligne 1159/2929 traitée : A
# Ligne 1160/2929 traitée : A
# Ligne 1161/2929 traitée : A
# Ligne 1162/2929 traitée : B
# Ligne 1163/2929 traitée : A
# Ligne 1164/2929 traitée : B
# Ligne 1165/2929 traitée : B
# Ligne 1166/2929 traitée : B
# Ligne 1167/2929 traitée : B
# Ligne 1168/2929 traitée : B
# Ligne 1169/2929 traitée : A
# Ligne 1170/2929 traitée : B
# Ligne 1171/2929 traitée : B
# Ligne 1172/2929 traitée : B
# Ligne 1173/2929 traitée : B
# Ligne 1174/2929 traitée : B
# Ligne 1175/2929 traitée : B
# Ligne 1176/2929 traitée : B
# Ligne 1177/2929 traitée : A
# Ligne 1178/2929 traitée : A
# Ligne 1179/2929 traitée : B
# Ligne 1180/2929 traitée : B
# Ligne 1181/2929 traitée : A
# Ligne 1182/2929 traitée : B
# Ligne 1183/2929 traitée : A
# Ligne 1184/2929 traitée : B
# Ligne 1185/2929 traitée : A
# Ligne 1186/2929 traitée : B
# Ligne 1187/2929 traitée : B
# Ligne 1188/2929 traitée : B
# Ligne 1189/2929 traitée : A
# Ligne 1190/2929 traitée : A
# Ligne 1191/2929 traitée : B
# Ligne 1192/2929 traitée : B
# Ligne 1193/2929 traitée : A
# Ligne 1194/2929 traitée : B
# Ligne 1195/2929 traitée : B
# Ligne 1196/2929 traitée : B
# Ligne 1197/2929 traitée : B
# Ligne 1198/2929 traitée : B
# Ligne 1199/2929 traitée : B
# Ligne 1200/2929 traitée : B
# Ligne 1201/2929 traitée : B
# Ligne 1202/2929 traitée : B
# Ligne 1203/2929 traitée : A
# Ligne 1204/2929 traitée : B
# Ligne 1205/2929 traitée : B
# Ligne 1206/2929 traitée : B
# Ligne 1207/2929 traitée : B
# Ligne 1208/2929 traitée : A
# Ligne 1209/2929 traitée : B
# Ligne 1210/2929 traitée : B
# Ligne 1211/2929 traitée : A
# Ligne 1212/2929 traitée : A
# Ligne 1213/2929 traitée : A
# Ligne 1214/2929 traitée : A
# Ligne 1215/2929 traitée : B
# Ligne 1216/2929 traitée : B
# Ligne 1217/2929 traitée : B
# Ligne 1218/2929 traitée : A
# Ligne 1219/2929 traitée : B
# Ligne 1220/2929 traitée : A
# Ligne 1221/2929 traitée : B
# Ligne 1222/2929 traitée : B
# Ligne 1223/2929 traitée : A
# Ligne 1224/2929 traitée : A
# Ligne 1225/2929 traitée : A
# Ligne 1226/2929 traitée : A
# Ligne 1227/2929 traitée : B
# Ligne 1228/2929 traitée : B
# Ligne 1229/2929 traitée : A
# Ligne 1230/2929 traitée : B
# Ligne 1231/2929 traitée : B
# Ligne 1232/2929 traitée : A
# Ligne 1233/2929 traitée : B
# Ligne 1234/2929 traitée : B
# Ligne 1235/2929 traitée : A
# Ligne 1236/2929 traitée : A
# Ligne 1237/2929 traitée : B
# Ligne 1238/2929 traitée : A
# Ligne 1239/2929 traitée : B
# Ligne 1240/2929 traitée : B
# Ligne 1241/2929 traitée : B
# Ligne 1242/2929 traitée : A
# Ligne 1243/2929 traitée : A
# Ligne 1244/2929 traitée : A
# Ligne 1245/2929 traitée : B
# Ligne 1246/2929 traitée : A
# Ligne 1247/2929 traitée : B
# Ligne 1248/2929 traitée : B
# Ligne 1249/2929 traitée : A
# Ligne 1250/2929 traitée : B
# Ligne 1251/2929 traitée : B
# Ligne 1252/2929 traitée : A
# Ligne 1253/2929 traitée : A
# Ligne 1254/2929 traitée : B
# Ligne 1255/2929 traitée : B
# Ligne 1256/2929 traitée : A
# Ligne 1257/2929 traitée : B
# Ligne 1258/2929 traitée : B
# Ligne 1259/2929 traitée : B
# Ligne 1260/2929 traitée : A
# Ligne 1261/2929 traitée : B
# Ligne 1262/2929 traitée : B
# Ligne 1263/2929 traitée : A
# Ligne 1264/2929 traitée : B
# Ligne 1265/2929 traitée : B
# Ligne 1266/2929 traitée : B
# Ligne 1267/2929 traitée : A
# Ligne 1268/2929 traitée : B
# Ligne 1269/2929 traitée : B
# Ligne 1270/2929 traitée : A
# Ligne 1271/2929 traitée : B
# Ligne 1272/2929 traitée : A
# Ligne 1273/2929 traitée : A
# Ligne 1274/2929 traitée : B
# Ligne 1275/2929 traitée : B
# Ligne 1276/2929 traitée : B
# Ligne 1277/2929 traitée : A
# Ligne 1278/2929 traitée : B
# Ligne 1279/2929 traitée : B
# Ligne 1280/2929 traitée : B
# Ligne 1281/2929 traitée : A
# Ligne 1282/2929 traitée : B
# Ligne 1283/2929 traitée : A
# Ligne 1284/2929 traitée : B
# Ligne 1285/2929 traitée : A
# Ligne 1286/2929 traitée : B
# Ligne 1287/2929 traitée : B
# Ligne 1288/2929 traitée : B
# Ligne 1289/2929 traitée : B
# Ligne 1290/2929 traitée : B
# Ligne 1291/2929 traitée : B
# Ligne 1292/2929 traitée : B
# Ligne 1293/2929 traitée : A
# Ligne 1294/2929 traitée : A
# Ligne 1295/2929 traitée : A
# Ligne 1296/2929 traitée : B
# Ligne 1297/2929 traitée : B
# Ligne 1298/2929 traitée : B
# Ligne 1299/2929 traitée : A
# Ligne 1300/2929 traitée : B
# Ligne 1301/2929 traitée : B
# Ligne 1302/2929 traitée : B
# Ligne 1303/2929 traitée : B
# Ligne 1304/2929 traitée : A
# Ligne 1305/2929 traitée : B
# Ligne 1306/2929 traitée : B
# Ligne 1307/2929 traitée : A
# Ligne 1308/2929 traitée : A
# Ligne 1309/2929 traitée : A
# Ligne 1310/2929 traitée : B
# Ligne 1311/2929 traitée : B
# Ligne 1312/2929 traitée : B
# Ligne 1313/2929 traitée : A
# Ligne 1314/2929 traitée : B
# Ligne 1315/2929 traitée : A
# Ligne 1316/2929 traitée : B
# Ligne 1317/2929 traitée : A
# Ligne 1318/2929 traitée : A
# Ligne 1319/2929 traitée : B
# Ligne 1320/2929 traitée : B
# Ligne 1321/2929 traitée : B
# Ligne 1322/2929 traitée : B
# Ligne 1323/2929 traitée : B
# Ligne 1324/2929 traitée : A
# Ligne 1325/2929 traitée : B
# Ligne 1326/2929 traitée : B
# Ligne 1327/2929 traitée : A
# Ligne 1328/2929 traitée : B
# Ligne 1329/2929 traitée : B
# Ligne 1330/2929 traitée : A
# Ligne 1331/2929 traitée : A
# Ligne 1332/2929 traitée : B
# Ligne 1333/2929 traitée : B
# Ligne 1334/2929 traitée : A
# Ligne 1335/2929 traitée : B
# Ligne 1336/2929 traitée : A
# Ligne 1337/2929 traitée : B
# Ligne 1338/2929 traitée : A
# Ligne 1339/2929 traitée : B
# Ligne 1340/2929 traitée : A
# Ligne 1341/2929 traitée : B
# Ligne 1342/2929 traitée : B
# Ligne 1343/2929 traitée : B
# Ligne 1344/2929 traitée : A
# Ligne 1345/2929 traitée : A
# Ligne 1346/2929 traitée : B
# Ligne 1347/2929 traitée : A
# Ligne 1348/2929 traitée : B
# Ligne 1349/2929 traitée : B
# Ligne 1350/2929 traitée : B
# Ligne 1351/2929 traitée : B
# Ligne 1352/2929 traitée : B
# Ligne 1353/2929 traitée : B
# Ligne 1354/2929 traitée : B
# Ligne 1355/2929 traitée : B
# Ligne 1356/2929 traitée : B
# Ligne 1357/2929 traitée : B
# Ligne 1358/2929 traitée : B
# Ligne 1359/2929 traitée : B
# Ligne 1360/2929 traitée : B
# Ligne 1361/2929 traitée : B
# Ligne 1362/2929 traitée : B
# Ligne 1363/2929 traitée : A
# Ligne 1364/2929 traitée : B
# Ligne 1365/2929 traitée : B
# Ligne 1366/2929 traitée : A
# Ligne 1367/2929 traitée : A
# Ligne 1368/2929 traitée : B
# Ligne 1369/2929 traitée : B
# Ligne 1370/2929 traitée : A
# Ligne 1371/2929 traitée : B
# Ligne 1372/2929 traitée : B
# Ligne 1373/2929 traitée : B
# Ligne 1374/2929 traitée : A
# Ligne 1375/2929 traitée : B
# Ligne 1376/2929 traitée : B
# Erreur avec l'API pour la ligne 1376 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1377/2929 traitée : Erreur
# Ligne 1378/2929 traitée : B
# Ligne 1379/2929 traitée : A
# Ligne 1380/2929 traitée : B
# Ligne 1381/2929 traitée : B
# Ligne 1382/2929 traitée : B
# Ligne 1383/2929 traitée : A
# Ligne 1384/2929 traitée : B
# Ligne 1385/2929 traitée : B
# Ligne 1386/2929 traitée : A
# Ligne 1387/2929 traitée : B
# Ligne 1388/2929 traitée : A
# Ligne 1389/2929 traitée : A
# Ligne 1390/2929 traitée : B
# Ligne 1391/2929 traitée : B
# Ligne 1392/2929 traitée : B
# Ligne 1393/2929 traitée : A
# Ligne 1394/2929 traitée : B
# Ligne 1395/2929 traitée : B
# Ligne 1396/2929 traitée : A
# Ligne 1397/2929 traitée : B
# Ligne 1398/2929 traitée : B
# Ligne 1399/2929 traitée : B
# Ligne 1400/2929 traitée : A
# Ligne 1401/2929 traitée : B
# Ligne 1402/2929 traitée : B
# Ligne 1403/2929 traitée : A
# Ligne 1404/2929 traitée : B
# Ligne 1405/2929 traitée : B
# Ligne 1406/2929 traitée : B
# Ligne 1407/2929 traitée : A
# Ligne 1408/2929 traitée : B
# Ligne 1409/2929 traitée : A
# Ligne 1410/2929 traitée : B
# Ligne 1411/2929 traitée : A
# Ligne 1412/2929 traitée : B
# Ligne 1413/2929 traitée : A
# Ligne 1414/2929 traitée : B
# Ligne 1415/2929 traitée : A
# Ligne 1416/2929 traitée : A
# Ligne 1417/2929 traitée : B
# Ligne 1418/2929 traitée : B
# Ligne 1419/2929 traitée : B
# Ligne 1420/2929 traitée : A
# Ligne 1421/2929 traitée : B
# Ligne 1422/2929 traitée : A
# Ligne 1423/2929 traitée : A
# Ligne 1424/2929 traitée : B
# Ligne 1425/2929 traitée : B
# Ligne 1426/2929 traitée : B
# Ligne 1427/2929 traitée : A
# Ligne 1428/2929 traitée : B
# Ligne 1429/2929 traitée : B
# Ligne 1430/2929 traitée : A
# Ligne 1431/2929 traitée : A
# Ligne 1432/2929 traitée : A
# Ligne 1433/2929 traitée : B
# Ligne 1434/2929 traitée : B
# Ligne 1435/2929 traitée : B
# Ligne 1436/2929 traitée : B
# Ligne 1437/2929 traitée : B
# Ligne 1438/2929 traitée : A
# Ligne 1439/2929 traitée : B
# Ligne 1440/2929 traitée : B
# Ligne 1441/2929 traitée : B
# Ligne 1442/2929 traitée : B
# Ligne 1443/2929 traitée : B
# Ligne 1444/2929 traitée : A
# Ligne 1445/2929 traitée : B
# Ligne 1446/2929 traitée : B
# Ligne 1447/2929 traitée : B
# Ligne 1448/2929 traitée : B
# Ligne 1449/2929 traitée : B
# Ligne 1450/2929 traitée : A
# Ligne 1451/2929 traitée : A
# Ligne 1452/2929 traitée : B
# Ligne 1453/2929 traitée : B
# Ligne 1454/2929 traitée : B
# Ligne 1455/2929 traitée : B
# Ligne 1456/2929 traitée : A
# Ligne 1457/2929 traitée : A
# Ligne 1458/2929 traitée : A
# Ligne 1459/2929 traitée : B
# Ligne 1460/2929 traitée : B
# Ligne 1461/2929 traitée : B
# Ligne 1462/2929 traitée : B
# Ligne 1463/2929 traitée : B
# Ligne 1464/2929 traitée : A
# Ligne 1465/2929 traitée : A
# Ligne 1466/2929 traitée : A
# Ligne 1467/2929 traitée : B
# Ligne 1468/2929 traitée : A
# Ligne 1469/2929 traitée : B
# Ligne 1470/2929 traitée : B
# Ligne 1471/2929 traitée : B
# Ligne 1472/2929 traitée : B
# Erreur avec l'API pour la ligne 1472 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1473/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1473 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1474/2929 traitée : Erreur
# Ligne 1475/2929 traitée : B
# Ligne 1476/2929 traitée : B
# Ligne 1477/2929 traitée : A
# Ligne 1478/2929 traitée : A
# Ligne 1479/2929 traitée : B
# Erreur avec l'API pour la ligne 1479 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1480/2929 traitée : Erreur
# Ligne 1481/2929 traitée : B
# Ligne 1482/2929 traitée : B
# Erreur avec l'API pour la ligne 1482 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1483/2929 traitée : Erreur
# Ligne 1484/2929 traitée : A
# Erreur avec l'API pour la ligne 1484 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1485/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1485 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1486/2929 traitée : Erreur
# Ligne 1487/2929 traitée : A
# Ligne 1488/2929 traitée : B
# Erreur avec l'API pour la ligne 1488 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1489/2929 traitée : Erreur
# Ligne 1490/2929 traitée : A
# Erreur avec l'API pour la ligne 1490 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1491/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1491 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1492/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1492 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1493/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1493 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1494/2929 traitée : Erreur
# Ligne 1495/2929 traitée : B
# Erreur avec l'API pour la ligne 1495 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1496/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1496 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1497/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1497 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1498/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1498 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1499/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1499 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1500/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1500 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1501/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1501 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1502/2929 traitée : Erreur
# Ligne 1503/2929 traitée : B
# Erreur avec l'API pour la ligne 1503 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1504/2929 traitée : Erreur
# Ligne 1505/2929 traitée : B
# Erreur avec l'API pour la ligne 1505 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1506/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1506 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1507/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1507 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1508/2929 traitée : Erreur
# Ligne 1509/2929 traitée : B
# Erreur avec l'API pour la ligne 1509 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1510/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1510 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1511/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1511 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1512/2929 traitée : Erreur
# Ligne 1513/2929 traitée : A
# Erreur avec l'API pour la ligne 1513 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1514/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1514 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1515/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1515 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1516/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1516 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1517/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1517 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1518/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1518 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1519/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1519 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1520/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1520 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1521/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1521 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1522/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1522 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1523/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1523 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1524/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1524 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1525/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1525 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1526/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1526 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1527/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1527 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1528/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1528 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1529/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1529 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1530/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1530 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1531/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1531 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1532/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1532 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1533/2929 traitée : Erreur
# Ligne 1534/2929 traitée : A
# Erreur avec l'API pour la ligne 1534 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1535/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1535 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1536/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1536 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1537/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1537 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1538/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1538 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1539/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1539 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1540/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1540 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1541/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1541 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1542/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1542 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1543/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 1543 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 1544/2929 traitée : Erreur
# ...
# Ligne 2801/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2801 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2802/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2802 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2803/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2803 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2804/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2804 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2805/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2805 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2806/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2806 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2807/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2807 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2808/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2808 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2809/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2809 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2810/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2810 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2811/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2811 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2812/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2812 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2813/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2813 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2814/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2814 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2815/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2815 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2816/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2816 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2817/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2817 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2818/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2818 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2819/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2819 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2820/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2820 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2821/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2821 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2822/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2822 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2823/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2823 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2824/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2824 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2825/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2825 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2826/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2826 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2827/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2827 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2828/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2828 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2829/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2829 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2830/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2830 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2831/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2831 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2832/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2832 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2833/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2833 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2834/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2834 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2835/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2835 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2836/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2836 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2837/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2837 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2838/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2838 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2839/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2839 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2840/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2840 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2841/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2841 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2842/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2842 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2843/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2843 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2844/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2844 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2845/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2845 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2846/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2846 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2847/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2847 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2848/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2848 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2849/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2849 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2850/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2850 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2851/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2851 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2852/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2852 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2853/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2853 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2854/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2854 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2855/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2855 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2856/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2856 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2857/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2857 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2858/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2858 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2859/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2859 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2860/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2860 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2861/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2861 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2862/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2862 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2863/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2863 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2864/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2864 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2865/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2865 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2866/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2866 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2867/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2867 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2868/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2868 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2869/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2869 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2870/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2870 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2871/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2871 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2872/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2872 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2873/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2873 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2874/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2874 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2875/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2875 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2876/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2876 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2877/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2877 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2878/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2878 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2879/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2879 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2880/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2880 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2881/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2881 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2882/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2882 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2883/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2883 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2884/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2884 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2885/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2885 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2886/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2886 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2887/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2887 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2888/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2888 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2889/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2889 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2890/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2890 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2891/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2891 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2892/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2892 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2893/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2893 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2894/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2894 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2895/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2895 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2896/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2896 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2897/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2897 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2898/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2898 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2899/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2899 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2900/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2900 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2901/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2901 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2902/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2902 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2903/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2903 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2904/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2904 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2905/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2905 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2906/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2906 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2907/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2907 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2908/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2908 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2909/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2909 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2910/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2910 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2911/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2911 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2912/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2912 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2913/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2913 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2914/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2914 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2915/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2915 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2916/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2916 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2917/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2917 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2918/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2918 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2919/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2919 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2920/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2920 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2921/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2921 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2922/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2922 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2923/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2923 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2924/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2924 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2925/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2925 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2926/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2926 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2927/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2927 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2928/2929 traitée : Erreur
# Erreur avec l'API pour la ligne 2928 : 429 Resource has been exhausted (e.g. check quota).
# Ligne 2929/2929 traitée : Erreur
# Traitement terminé. Fichier final sauvegardé dans : C:\Users\amirb\Downloads\train_gemini.csv
